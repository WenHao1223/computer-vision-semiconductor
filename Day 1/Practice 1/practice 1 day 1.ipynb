# %%
# 1️⃣ Install dependencies (if not already installed)
# !pip install opencv-python matplotlib --quiet

# %%
# 2️⃣ Import libraries
import cv2
import matplotlib.pyplot as plt
from google.colab import files

# %%
# 3️⃣ Upload an image (e.g., wafer_sample.png)
print("📤 Please upload your image (e.g., wafer_sample.png):")
uploaded = files.upload()
# Out:
# 📤 Please upload your image (e.g., wafer_sample.png):
#      <input type="file" id="files-b2d60328-7640-462c-8ee8-b33aa5a343e2" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-b2d60328-7640-462c-8ee8-b33aa5a343e2">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# ...

# %%
# Get uploaded filename
image_path = list(uploaded.keys())[0]
print(f"✅ Uploaded: {image_path}")
# Out:
# ✅ Uploaded: 002.png

# %%
# 4️⃣ Load and preprocess image
img = cv2.imread(image_path)
img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
img_gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# %%
# 5️⃣ Define ROI (adjust x, y, w, h as needed)
x, y, w, h = 0, 140, 200, 200
roi = img_rgb[y:y+h-80, x:x+w-80]

# %%
# 6️⃣ Plot
plt.figure(figsize=(12, 4))

plt.subplot(1, 3, 1)
plt.title("Original (RGB)")
plt.imshow(img_rgb)
plt.axis('off')

plt.subplot(1, 3, 2)
plt.title("Grayscale")
plt.imshow(img_gray, cmap='gray')
plt.axis('off')

plt.subplot(1, 3, 3)
plt.title("ROI Focus Area")
plt.imshow(roi)
plt.axis('off')

plt.show()

# %%
output_filename = "roi.png"
plt.imsave(output_filename, roi)
print(f" Roi image saved as: {output_filename}")
# Out:
#  Roi image saved as: roi.png

# %%
from google.colab import files
files.download(output_filename)
