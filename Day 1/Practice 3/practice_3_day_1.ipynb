# %%
# ======================================================
# ✅ Edge Detection (Custom Image + Auto Save & Download)
# ======================================================

# Step 1️⃣: Import necessary librariesa
import cv2
import matplotlib.pyplot as plt
from google.colab import files
import numpy as np
import zipfile
import os

# %%
# Step 2️⃣: Upload an image
print("📤 Please upload your image (JPG/PNG):")
uploaded = files.upload()
# Out:
# 📤 Please upload your image (JPG/PNG):
#      <input type="file" id="files-332df7b1-4dc3-4f3b-b336-4490206f891a" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-332df7b1-4dc3-4f3b-b336-4490206f891a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# ...

# %%
# Step 3️⃣: Read the uploaded image (as grayscale)
image_path = next(iter(uploaded))
image = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)

if image is None:
    raise ValueError("❌ Failed to load image. Please upload a valid image file.")

# %%
# Step 4️⃣: Apply Gaussian Blur to reduce noise
blurred_image = cv2.GaussianBlur(image, (5, 5), 1.4)

# %%
# Step 5️⃣: Apply Canny Edge Detection
edges = cv2.Canny(blurred_image, 50, 150)

# %%
# Step 6️⃣: Display results
plt.figure(figsize=(10, 5))

plt.subplot(1, 2, 1)
plt.title('Original Image')
plt.imshow(image, cmap='gray')
plt.axis('off')

plt.subplot(1, 2, 2)
plt.title('Edge Detected Image (Canny)')
plt.imshow(edges, cmap='gray')
plt.axis('off')

plt.tight_layout()
plt.show()

# %%
# Step 7️⃣: Save both images
output_dir = "edge_detection_outputs"
os.makedirs(output_dir, exist_ok=True)

original_path = os.path.join(output_dir, "original_image.png")
edges_path = os.path.join(output_dir, "edge_detected_image.png")

cv2.imwrite(original_path, image)
cv2.imwrite(edges_path, edges)
# Out:
# True

# %%
# Step 8️⃣: Zip and download
zip_filename = "edge_detection_results.zip"
with zipfile.ZipFile(zip_filename, "w") as zipf:
    zipf.write(original_path)
    zipf.write(edges_path)

files.download(zip_filename)
print(f"✅ All images saved and downloaded as: {zip_filename}")
# Out:
# ✅ All images saved and downloaded as: edge_detection_results.zip
